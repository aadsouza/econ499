# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
rifdata8388 = pd.read_excel("/Users/amedeusdsouza/econ499/linreg/rifreg2_coefs_1.xlsx")
rifdata8800 = pd.read_excel("/Users/amedeusdsouza/econ499/linreg/rifreg2_coefs_2.xlsx")
rifdata0019 = pd.read_excel("/Users/amedeusdsouza/econ499/linreg/rifreg2_coefs_3.xlsx")

# %%
men8388 = rifdata8388[rifdata8388.name.str.startswith("m")]
wom8388 = rifdata8388[rifdata8388.name.str.startswith("f")]

men8800 = rifdata8800[rifdata8800.name.str.startswith("m")]
wom8800 = rifdata8800[rifdata8800.name.str.startswith("f")]

men0019 = rifdata0019[rifdata0019.name.str.startswith("m")]
wom0019 = rifdata0019[rifdata0019.name.str.startswith("f")]

# %%
pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# # Men

# %%
#Black wage penalty for all men along distribution 8388
blackmen8388 = men8388[men8388.name.str.startswith("m_blackrelwhite")]
blackmen8388["percentile"] = blackmen8388["name"].str.strip().str[-2:].astype(int)

blackmen8388["ols"] =  -.1704068
blackmen8388["lbols"] = -.1811841
blackmen8388["ubols"] = -.1596294

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(blackmen8388.percentile, blackmen8388.coef, color = "darkviolet")
# ax.fill_between(blackmen8388.percentile, blackmen8388.lb, blackmen8388.ub, color = "hotpink", alpha = 0.1)
# ax.plot(blackmen8388.percentile, blackmen8388.ols, color = "orange")
# ax.fill_between(blackmen8388.percentile, blackmen8388.lbols, blackmen8388.ubols, alpha = 0.1, color = "orange")
# ax.set_yticks(np.arange(-0.4, 0.4, step=0.05))
# ax

# %%
#Black wage penalty for all men along distribution 8800
blackmen8800 = men8800[men8800.name.str.startswith("m_blackrelwhite")]
blackmen8800["percentile"] = blackmen8800["name"].str.strip().str[-2:].astype(int)

blackmen8800["ols"] = -.1692789
blackmen8800["lbols"] = -.1774905
blackmen8800["ubols"] = -.1610673

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(blackmen8800.percentile, blackmen8800.coef, color = "darkviolet")
# ax.fill_between(blackmen8800.percentile, blackmen8800.lb, blackmen8800.ub, color = "hotpink", alpha = 0.1)
# ax.plot(blackmen8800.percentile, blackmen8800.ols, color = "orange")
# ax.fill_between(blackmen8800.percentile, blackmen8800.lbols, blackmen8800.ubols, alpha = 0.1, color = "orange")

# %%
#Black wage penalty for all men along distribution 0019
blackmen0019 = men0019[men0019.name.str.startswith("m_blackrelwhite")]
blackmen0019["percentile"] = blackmen0019["name"].str.strip().str[-2:].astype(int)

blackmen0019["ols"] = -.163326 
blackmen0019["lbols"] = -.1702075
blackmen0019["ubols"] = -.1564445

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(blackmen0019.percentile, blackmen0019.coef, color = "darkviolet")
# ax.fill_between(blackmen0019.percentile, blackmen0019.lb, blackmen0019.ub, color = "hotpink", alpha = 0.1)
# ax.plot(blackmen0019.percentile, blackmen0019.ols, color = "orange")
# ax.fill_between(blackmen0019.percentile, blackmen0019.lbols, blackmen0019.ubols, alpha = 0.1, color = "orange")

# %%
#Association between coverage and wages for all men along distribution 8388
coveredmen8388 = men8388[men8388.name.str.startswith("m_covered")]
coveredmen8388["percentile"] = coveredmen8388["name"].str.strip().str[-2:].astype(int)

coveredmen8388["ols"] = .1897432
coveredmen8388["lbols"] = .1694347
coveredmen8388["ubols"] = .2100517

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(coveredmen8388.percentile, coveredmen8388.coef)
# ax.fill_between(coveredmen8388.percentile, coveredmen8388.lb, coveredmen8388.ub, alpha = 0.1)
# ax.plot(coveredmen8388.percentile, coveredmen8388.ols, color = "orange")
# ax.fill_between(coveredmen8388.percentile, coveredmen8388.lbols, coveredmen8388.ubols, alpha = 0.1, color = "orange")

# %%
#Association between coverage and wages for all men along distribution 8800
coveredmen8800 = men8800[men8800.name.str.startswith("m_covered")]
coveredmen8800["percentile"] = coveredmen8800["name"].str.strip().str[-2:].astype(int)

coveredmen8800["ols"] = .1786086
coveredmen8800["lbols"] = .1637689
coveredmen8800["ubols"] = .1934483

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(coveredmen8800.percentile, coveredmen8800.coef)
# ax.fill_between(coveredmen8800.percentile, coveredmen8800.lb, coveredmen8800.ub, alpha = 0.1)
# ax.plot(coveredmen8800.percentile, coveredmen8800.ols, color = "orange")
# ax.fill_between(coveredmen8800.percentile, coveredmen8800.lbols, coveredmen8800.ubols, alpha = 0.1, color = "orange")

# %%
#Association between coverage and wages for all men along distribution 0019
coveredmen0019 = men0019[men0019.name.str.startswith("m_covered")]
coveredmen0019["percentile"] = coveredmen0019["name"].str.strip().str[-2:].astype(int)

coveredmen0019["ols"] = .1711622
coveredmen0019["lbols"] = .1563396
coveredmen0019["ubols"] = .1859848

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(coveredmen0019.percentile, coveredmen0019.coef)
# ax.fill_between(coveredmen0019.percentile, coveredmen0019.lb, coveredmen0019.ub, alpha = 0.1)
# ax.plot(coveredmen0019.percentile, coveredmen0019.ols, color = "orange")
# ax.fill_between(coveredmen0019.percentile, coveredmen0019.lbols, coveredmen0019.ubols, alpha = 0.1, color = "orange")

# %%
#Association between coverageblackrelwhite and wages for all men along distribution 8388
timesmen8388 = men8388[men8388.name.str.startswith("m_times")]
timesmen8388["percentile"] = timesmen8388["name"].str.strip().str[-2:].astype(int)

timesmen8388["ols"] = .0440587
timesmen8388["lbols"] = .0248311
timesmen8388["ubols"] = .0632864

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(timesmen8388.percentile, timesmen8388.coef, color = "darkviolet")
# ax.fill_between(timesmen8388.percentile, timesmen8388.lb, timesmen8388.ub, color = "hotpink", alpha = 0.1)
# ax.plot(timesmen8388.percentile, timesmen8388.ols, color = "orange")
# ax.fill_between(timesmen8388.percentile, timesmen8388.lbols, timesmen8388.ubols, alpha = 0.1, color = "orange")

# %%
#Association between coverageblackrelwhite and wages for all men along distribution 8800
timesmen8800 = men8800[men8800.name.str.startswith("m_times")]
timesmen8800["percentile"] = timesmen8800["name"].str.strip().str[-2:].astype(int)

timesmen8800["ols"] = .030419
timesmen8800["lbols"] = .0127354
timesmen8800["ubols"] = .0481025

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(timesmen8800.percentile, timesmen8800.coef, color = "darkviolet")
# ax.fill_between(timesmen8800.percentile, timesmen8800.lb, timesmen8800.ub, color = "hotpink", alpha = 0.1)
# ax.plot(timesmen8800.percentile, timesmen8800.ols, color = "orange")
# ax.fill_between(timesmen8800.percentile, timesmen8800.lbols, timesmen8800.ubols, alpha = 0.1, color = "orange")

# %%
#Association between coverageblackrelwhite and wages for all men along distribution 0019
timesmen0019 = men0019[men0019.name.str.startswith("m_times")]
timesmen0019["percentile"] = timesmen0019["name"].str.strip().str[-2:].astype(int)

timesmen0019["ols"] = .0262197
timesmen0019["lbols"] = .0110926
timesmen0019["ubols"] = .0413467

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(timesmen0019.percentile, timesmen0019.coef, color = "darkviolet")
# ax.fill_between(timesmen0019.percentile, timesmen0019.lb, timesmen0019.ub, color = "hotpink", alpha = 0.1)
# ax.plot(timesmen0019.percentile, timesmen0019.ols, color = "orange")
# ax.fill_between(timesmen0019.percentile, timesmen0019.lbols, timesmen0019.ubols, alpha = 0.1, color = "orange")

# %%
# Table RIF-OLS Regression of Real Log Wages on Union Coverage and Race - Men
fig, ax = plt.subplots(3,3, figsize = (35, 20), sharey = True, sharex = True)

for i in [0,1,2]:
    for j in [0,1,2]:
        ax[i,j].set_yticks(np.arange(-0.5, 0.5, step=0.05))
        ax[i,j].xaxis.set_tick_params(labelbottom=True)
        ax[i,j].yaxis.set_tick_params(labelbottom=True)
        ax[i,j].set_xlabel("Percentiles for All (Black and White) Men")
        ax[i,j].set_ylabel("Real Log Wages")

#8388 Black
ax[0,0].axhline(y = 0, color = "black", linestyle ="--")
ax[0,0].plot(blackmen8388.percentile, blackmen8388.coef, color = "darkviolet")
ax[0,0].fill_between(blackmen8388.percentile, blackmen8388.lb, blackmen8388.ub, color = "hotpink", alpha = 0.1)
ax[0,0].plot(blackmen8388.percentile, blackmen8388.ols, color = "orange")
ax[0,0].fill_between(blackmen8388.percentile, blackmen8388.lbols, blackmen8388.ubols, alpha = 0.1, color = "orange")

#8800 Black
ax[0,1].axhline(y = 0, color = "black", linestyle ="--")
ax[0,1].plot(blackmen8800.percentile, blackmen8800.coef, color = "darkviolet")
ax[0,1].fill_between(blackmen8800.percentile, blackmen8800.lb, blackmen8800.ub, color = "hotpink", alpha = 0.1)
ax[0,1].plot(blackmen8800.percentile, blackmen8800.ols, color = "orange")
ax[0,1].fill_between(blackmen8800.percentile, blackmen8800.lbols, blackmen8800.ubols, alpha = 0.1, color = "orange")

#0019 Black
ax[0,2].axhline(y = 0, color = "black", linestyle ="--")
ax[0,2].plot(blackmen0019.percentile, blackmen0019.coef, color = "darkviolet")
ax[0,2].fill_between(blackmen0019.percentile, blackmen0019.lb, blackmen0019.ub, color = "hotpink", alpha = 0.1)
ax[0,2].plot(blackmen0019.percentile, blackmen0019.ols, color = "orange")
ax[0,2].fill_between(blackmen0019.percentile, blackmen0019.lbols, blackmen0019.ubols, alpha = 0.1, color = "orange")

#8388 Covered
ax[1,0].axhline(y = 0, color = "black", linestyle ="--")
ax[1,0].plot(coveredmen8388.percentile, coveredmen8388.coef)
ax[1,0].fill_between(coveredmen8388.percentile, coveredmen8388.lb, coveredmen8388.ub, alpha = 0.1)
ax[1,0].plot(coveredmen8388.percentile, coveredmen8388.ols, color = "orange")
ax[1,0].fill_between(coveredmen8388.percentile, coveredmen8388.lbols, coveredmen8388.ubols, alpha = 0.1, color = "orange")

#8800 Covered
ax[1,1].axhline(y = 0, color = "black", linestyle ="--")
ax[1,1].plot(coveredmen8800.percentile, coveredmen8800.coef)
ax[1,1].fill_between(coveredmen8800.percentile, coveredmen8800.lb, coveredmen8800.ub, alpha = 0.1)
ax[1,1].plot(coveredmen8800.percentile, coveredmen8800.ols, color = "orange")
ax[1,1].fill_between(coveredmen8800.percentile, coveredmen8800.lbols, coveredmen8800.ubols, alpha = 0.1, color = "orange")

#0019 Covered
ax[1,2].axhline(y = 0, color = "black", linestyle ="--")
ax[1,2].plot(coveredmen0019.percentile, coveredmen0019.coef)
ax[1,2].fill_between(coveredmen0019.percentile, coveredmen0019.lb, coveredmen0019.ub, alpha = 0.1)
ax[1,2].plot(coveredmen0019.percentile, coveredmen0019.ols, color = "orange")
ax[1,2].fill_between(coveredmen0019.percentile, coveredmen0019.lbols, coveredmen0019.ubols, alpha = 0.1, color = "orange")

#8388 Times
ax[2,0].axhline(y = 0, color = "black", linestyle ="--")
ax[2,0].plot(timesmen8388.percentile, timesmen8388.coef, color = "darkviolet")
ax[2,0].fill_between(timesmen8388.percentile, timesmen8388.lb, timesmen8388.ub, color = "hotpink", alpha = 0.1)
ax[2,0].plot(timesmen8388.percentile, timesmen8388.ols, color = "orange")
ax[2,0].fill_between(timesmen8388.percentile, timesmen8388.lbols, timesmen8388.ubols, alpha = 0.1, color = "orange")

#8800 Times
ax[2,1].axhline(y = 0, color = "black", linestyle ="--")
ax[2,1].plot(timesmen8800.percentile, timesmen8800.coef, color = "darkviolet")
ax[2,1].fill_between(timesmen8800.percentile, timesmen8800.lb, timesmen8800.ub, color = "hotpink", alpha = 0.1)
ax[2,1].plot(timesmen8800.percentile, timesmen8800.ols, color = "orange")
ax[2,1].fill_between(timesmen8800.percentile, timesmen8800.lbols, timesmen8800.ubols, alpha = 0.1, color = "orange")

#0019 Times
ax[2,2].axhline(y = 0, color = "black", linestyle ="--")
ax[2,2].plot(timesmen0019.percentile, timesmen0019.coef, color = "darkviolet")
ax[2,2].fill_between(timesmen0019.percentile, timesmen0019.lb, timesmen0019.ub, color = "hotpink", alpha = 0.1)
ax[2,2].plot(timesmen0019.percentile, timesmen0019.ols, color = "orange")
ax[2,2].fill_between(timesmen0019.percentile, timesmen0019.lbols, timesmen0019.ubols, alpha = 0.1, color = "orange")


cols = ['{}'.format(col) for col in ["1983-1988", "1988-2000", "2000-2019"]]
rows = ['{}'.format(row) for row in ["Black", "Covered", "Covered * Black"]]

pad = 5 # in points

for a, col in zip(ax[0], cols):
    a.annotate(col, xy=(0.5, 1), xytext=(0, pad),
                xycoords='axes fraction', textcoords='offset points',
                size=27, ha='center', va='baseline')

for a, row in zip(ax[:,0], rows):
    a.annotate(row, xy=(0, 0.5), xytext=(-a.yaxis.labelpad - pad, 0),
                xycoords=a.yaxis.label, textcoords='offset points',
                size=27, ha='right', va='center')


fig.subplots_adjust(left=0.15, top=0.95)

plt.show()

# %% [markdown]
# # Women

# %%
#Black wage penalty for all wom along distribution 8388
blackwom8388 = wom8388[wom8388.name.str.startswith("f_blackrelwhite")]
blackwom8388["percentile"] = blackwom8388["name"].str.strip().str[-2:].astype(int)

blackwom8388["ols"] = -.0692777
blackwom8388["lbols"] = -.0806003
blackwom8388["ubols"] = -.0579551

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(blackwom8388.percentile, blackwom8388.coef, color = "darkviolet")
# ax.fill_between(blackwom8388.percentile, blackwom8388.lb, blackwom8388.ub, color = "hotpink", alpha = 0.1)
# ax.plot(blackwom8388.percentile, blackwom8388.ols, color = "orange")
# ax.fill_between(blackwom8388.percentile, blackwom8388.lbols, blackwom8388.ubols, alpha = 0.1, color = "orange")

# %%
#Black wage penalty for all wom along distribution 8800
blackwom8800 = wom8800[wom8800.name.str.startswith("f_blackrelwhite")]
blackwom8800["percentile"] = blackwom8800["name"].str.strip().str[-2:].astype(int)

blackwom8800["ols"] = -.0911844
blackwom8800["lbols"] = -.0993272
blackwom8800["ubols"] = -.0830415

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(blackwom8800.percentile, blackwom8800.coef, color = "darkviolet")
# ax.fill_between(blackwom8800.percentile, blackwom8800.lb, blackwom8800.ub, color = "hotpink", alpha = 0.1)
# ax.plot(blackwom8800.percentile, blackwom8800.ols, color = "orange")
# ax.fill_between(blackwom8800.percentile, blackwom8800.lbols, blackwom8800.ubols, alpha = 0.1, color = "orange")

# %%
#Black wage penalty for all wom along distribution 0019
blackwom0019 = wom0019[wom0019.name.str.startswith("f_blackrelwhite")]
blackwom0019["percentile"] = blackwom0019["name"].str.strip().str[-2:].astype(int)

blackwom0019["ols"] = -.1028154
blackwom0019["lbols"] = -.1111846
blackwom0019["ubols"] = -.0944461

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(blackwom0019.percentile, blackwom0019.coef, color = "darkviolet")
# ax.fill_between(blackwom0019.percentile, blackwom0019.lb, blackwom0019.ub, color = "hotpink", alpha = 0.1)
# ax.plot(blackwom0019.percentile, blackwom0019.ols, color = "orange")
# ax.fill_between(blackwom0019.percentile, blackwom0019.lbols, blackwom0019.ubols, alpha = 0.1, color = "orange")

# %%
#Association between coverage and wages for all wom along distribution 8388
coveredwom8388 = wom8388[wom8388.name.str.startswith("f_covered")]
coveredwom8388["percentile"] = coveredwom8388["name"].str.strip().str[-2:].astype(int)

coveredwom8388["ols"] = .1734068
coveredwom8388["lbols"] = .1568123
coveredwom8388["ubols"] = .1900013

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(coveredwom8388.percentile, coveredwom8388.coef)
# ax.fill_between(coveredwom8388.percentile, coveredwom8388.lb, coveredwom8388.ub, alpha = 0.1)
# ax.plot(coveredwom8388.percentile, coveredwom8388.ols, color = "orange")
# ax.fill_between(coveredwom8388.percentile, coveredwom8388.lbols, coveredwom8388.ubols, alpha = 0.1, color = "orange")

# %%
#Association between coverage and wages for all wom along distribution 8800
coveredwom8800 = wom8800[wom8800.name.str.startswith("f_covered")]
coveredwom8800["percentile"] = coveredwom8800["name"].str.strip().str[-2:].astype(int)

coveredwom8800["ols"] = .1506813
coveredwom8800["lbols"] = .1381185
coveredwom8800["ubols"] = .1632441

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(coveredwom8800.percentile, coveredwom8800.coef)
# ax.fill_between(coveredwom8800.percentile, coveredwom8800.lb, coveredwom8800.ub, alpha = 0.1)
# ax.plot(coveredwom8800.percentile, coveredwom8800.ols, color = "orange")
# ax.fill_between(coveredwom8800.percentile, coveredwom8800.lbols, coveredwom8800.ubols, alpha = 0.1, color = "orange")

# %%
#Association between coverage and wages for all wom along distribution 0019
coveredwom0019 = wom0019[wom0019.name.str.startswith("f_covered")]
coveredwom0019["percentile"] = coveredwom0019["name"].str.strip().str[-2:].astype(int)

coveredwom0019["ols"] = .1202241
coveredwom0019["lbols"] = .1064696
coveredwom0019["ubols"] = .1339786

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(coveredwom0019.percentile, coveredwom0019.coef)
# ax.fill_between(coveredwom0019.percentile, coveredwom0019.lb, coveredwom0019.ub, alpha = 0.1)
# ax.plot(coveredwom0019.percentile, coveredwom0019.ols, color = "orange")
# ax.fill_between(coveredwom0019.percentile, coveredwom0019.lbols, coveredwom0019.ubols, alpha = 0.1, color = "orange")

# %%
#Association between coverageblackrelwhite and wages for all wom along distribution 8388
timeswom8388 = wom8388[wom8388.name.str.startswith("f_times")]
timeswom8388["percentile"] = timeswom8388["name"].str.strip().str[-2:].astype(int)

timeswom8388["ols"] = .0160247
timeswom8388["lbols"] = -.002065
timeswom8388["ubols"] = .0341143

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(timeswom8388.percentile, timeswom8388.coef, color = "darkviolet")
# ax.fill_between(timeswom8388.percentile, timeswom8388.lb, timeswom8388.ub, color = "hotpink", alpha = 0.1)
# ax.plot(timeswom8388.percentile, timeswom8388.ols, color = "orange")
# ax.fill_between(timeswom8388.percentile, timeswom8388.lbols, timeswom8388.ubols, alpha = 0.1, color = "orange")

# %%
#Association between coverageblackrelwhite and wages for all wom along distribution 8800
timeswom8800 = wom8800[wom8800.name.str.startswith("f_times")]
timeswom8800["percentile"] = timeswom8800["name"].str.strip().str[-2:].astype(int)

timeswom8800["ols"] = .0335624
timeswom8800["lbols"] = .015781
timeswom8800["ubols"] = .0513437

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(timeswom8800.percentile, timeswom8800.coef, color = "darkviolet")
# ax.fill_between(timeswom8800.percentile, timeswom8800.lb, timeswom8800.ub, color = "hotpink", alpha = 0.1)
# ax.plot(timeswom8800.percentile, timeswom8800.ols, color = "orange")
# ax.fill_between(timeswom8800.percentile, timeswom8800.lbols, timeswom8800.ubols, alpha = 0.1, color = "orange")

# %%
#Association between coverageblackrelwhite and wages for all wom along distribution 0019
timeswom0019 = wom0019[wom0019.name.str.startswith("f_times")]
timeswom0019["percentile"] = timeswom0019["name"].str.strip().str[-2:].astype(int)

timeswom0019["ols"] = .040467
timeswom0019["lbols"] = .0246263
timeswom0019["ubols"] = .0563076

# fig, ax = plt.subplots()
# ax.axhline(y = 0, color = "black", linestyle ="--")
# ax.plot(timeswom0019.percentile, timeswom0019.coef, color = "darkviolet")
# ax.fill_between(timeswom0019.percentile, timeswom0019.lb, timeswom0019.ub, color = "hotpink", alpha = 0.1)
# ax.plot(timeswom0019.percentile, timeswom0019.ols, color = "orange")
# ax.fill_between(timeswom0019.percentile, timeswom0019.lbols, timeswom0019.ubols, alpha = 0.1, color = "orange")

# %%
# Table RIF-OLS Regression of Real Log Wages on Union Coverage and Race - Women
fig, ax = plt.subplots(3,3, figsize = (35, 20), sharey = True, sharex = True)

for i in [0,1,2]:
    for j in [0,1,2]:
        ax[i,j].set_yticks(np.arange(-0.5, 0.5, step=0.05))
        ax[i,j].xaxis.set_tick_params(labelbottom=True)
        ax[i,j].yaxis.set_tick_params(labelbottom=True)
        ax[i,j].set_xlabel("Percentiles for All (Black and White) Women")
        ax[i,j].set_ylabel("Real Log Wages")

#8388 Black
ax[0,0].axhline(y = 0, color = "black", linestyle ="--")
ax[0,0].plot(blackwom8388.percentile, blackwom8388.coef, color = "darkviolet")
ax[0,0].fill_between(blackwom8388.percentile, blackwom8388.lb, blackwom8388.ub, color = "hotpink", alpha = 0.1)
ax[0,0].plot(blackwom8388.percentile, blackwom8388.ols, color = "orange")
ax[0,0].fill_between(blackwom8388.percentile, blackwom8388.lbols, blackwom8388.ubols, alpha = 0.1, color = "orange")

#8800 Black
ax[0,1].axhline(y = 0, color = "black", linestyle ="--")
ax[0,1].plot(blackwom8800.percentile, blackwom8800.coef, color = "darkviolet")
ax[0,1].fill_between(blackwom8800.percentile, blackwom8800.lb, blackwom8800.ub, color = "hotpink", alpha = 0.1)
ax[0,1].plot(blackwom8800.percentile, blackwom8800.ols, color = "orange")
ax[0,1].fill_between(blackwom8800.percentile, blackwom8800.lbols, blackwom8800.ubols, alpha = 0.1, color = "orange")

#0019 Black
ax[0,2].axhline(y = 0, color = "black", linestyle ="--")
ax[0,2].plot(blackwom0019.percentile, blackwom0019.coef, color = "darkviolet")
ax[0,2].fill_between(blackwom0019.percentile, blackwom0019.lb, blackwom0019.ub, color = "hotpink", alpha = 0.1)
ax[0,2].plot(blackwom0019.percentile, blackwom0019.ols, color = "orange")
ax[0,2].fill_between(blackwom0019.percentile, blackwom0019.lbols, blackwom0019.ubols, alpha = 0.1, color = "orange")

#8388 Covered
ax[1,0].axhline(y = 0, color = "black", linestyle ="--")
ax[1,0].plot(coveredwom8388.percentile, coveredwom8388.coef)
ax[1,0].fill_between(coveredwom8388.percentile, coveredwom8388.lb, coveredwom8388.ub, alpha = 0.1)
ax[1,0].plot(coveredwom8388.percentile, coveredwom8388.ols, color = "orange")
ax[1,0].fill_between(coveredwom8388.percentile, coveredwom8388.lbols, coveredwom8388.ubols, alpha = 0.1, color = "orange")

#8800 Covered
ax[1,1].axhline(y = 0, color = "black", linestyle ="--")
ax[1,1].plot(coveredwom8800.percentile, coveredwom8800.coef)
ax[1,1].fill_between(coveredwom8800.percentile, coveredwom8800.lb, coveredwom8800.ub, alpha = 0.1)
ax[1,1].plot(coveredwom8800.percentile, coveredwom8800.ols, color = "orange")
ax[1,1].fill_between(coveredwom8800.percentile, coveredwom8800.lbols, coveredwom8800.ubols, alpha = 0.1, color = "orange")

#0019 Covered
ax[1,2].axhline(y = 0, color = "black", linestyle ="--")
ax[1,2].plot(coveredwom0019.percentile, coveredwom0019.coef)
ax[1,2].fill_between(coveredwom0019.percentile, coveredwom0019.lb, coveredwom0019.ub, alpha = 0.1)
ax[1,2].plot(coveredwom0019.percentile, coveredwom0019.ols, color = "orange")
ax[1,2].fill_between(coveredwom0019.percentile, coveredwom0019.lbols, coveredwom0019.ubols, alpha = 0.1, color = "orange")

#8388 Times
ax[2,0].axhline(y = 0, color = "black", linestyle ="--")
ax[2,0].plot(timeswom8388.percentile, timeswom8388.coef, color = "darkviolet")
ax[2,0].fill_between(timeswom8388.percentile, timeswom8388.lb, timeswom8388.ub, color = "hotpink", alpha = 0.1)
ax[2,0].plot(timeswom8388.percentile, timeswom8388.ols, color = "orange")
ax[2,0].fill_between(timeswom8388.percentile, timeswom8388.lbols, timeswom8388.ubols, alpha = 0.1, color = "orange")

#8800 Times
ax[2,1].axhline(y = 0, color = "black", linestyle ="--")
ax[2,1].plot(timeswom8800.percentile, timeswom8800.coef, color = "darkviolet")
ax[2,1].fill_between(timeswom8800.percentile, timeswom8800.lb, timeswom8800.ub, color = "hotpink", alpha = 0.1)
ax[2,1].plot(timeswom8800.percentile, timeswom8800.ols, color = "orange")
ax[2,1].fill_between(timeswom8800.percentile, timeswom8800.lbols, timeswom8800.ubols, alpha = 0.1, color = "orange")

#0019 Times
ax[2,2].axhline(y = 0, color = "black", linestyle ="--")
ax[2,2].plot(timeswom0019.percentile, timeswom0019.coef, color = "darkviolet")
ax[2,2].fill_between(timeswom0019.percentile, timeswom0019.lb, timeswom0019.ub, color = "hotpink", alpha = 0.1)
ax[2,2].plot(timeswom0019.percentile, timeswom0019.ols, color = "orange")
ax[2,2].fill_between(timeswom0019.percentile, timeswom0019.lbols, timeswom0019.ubols, alpha = 0.1, color = "orange")


cols = ['{}'.format(col) for col in ["1983-1988", "1988-2000", "2000-2019"]]
rows = ['{}'.format(row) for row in ["Black", "Covered", "Covered * Black"]]

pad = 5 # in points

for a, col in zip(ax[0], cols):
    a.annotate(col, xy=(0.5, 1), xytext=(0, pad),
                xycoords='axes fraction', textcoords='offset points',
                size=27, ha='center', va='baseline')

for a, row in zip(ax[:,0], rows):
    a.annotate(row, xy=(0, 0.5), xytext=(-a.yaxis.labelpad - pad, 0),
                xycoords=a.yaxis.label, textcoords='offset points',
                size=27, ha='right', va='center')


fig.subplots_adjust(left=0.15, top=0.95)

plt.show()
